# %%
ls
# Out:
# 1_notmnist.ipynb  notMNIST_large.tar.gz  notMNIST_small.tar.gz
# notMNIST_large/   notMNIST_small/        uda.ipynb

# %%
import os
print os.listdir("notMNIST_large/A/")
# Out:
# ['QW1lcmljYW5hIERyZWFtcyBDb25kVXByaWdodC50dGY=.png', 'QW5keSBEdWZyZXNuZS50dGY=.png', 'SFlcdWQyYjlcdWMyMThcdWJiMzhcdWM3OTAyLnR0Zg==.png', 'U2VyaWZHb3RoaWNFRi1IZWF2eS5vdGY=.png', 'UDIyUm9kaW5FeHRyYXMub3Rm.png', 'Um9tYW5GaXhlZC13aWR0aCBCb2xkLnR0Zg==.png', 'TWVwcERpc3BsYXlTaGFkb3cudHRm.png', 'U0YgQmlnIFdoaXNrZXkgQ29uZGVuc2VkLnR0Zg==.png', 'Q2FzdGVsbGFyLnR0Zg==.png', 'QWxiZXJ0dXNNVC1JdGFsaWMub3Rm.png', 'UmVuYXJkTm8zLUl0YWxpYy5vdGY=.png', 'QWxkaW5lIDcyMSBMaWdodCBJdGFsaWMucGZi.png', 'QnJ1c2hTdHJva2VIb2xsb3cgUmVndWxhci50dGY=.png', 'THlkaWFuIEl0YWxpYyBCVC50dGY=.png', 'TEEgSGVhZGxpZ2h0cyBCVE4gQm9sZEl0YWxpYy50dGY=.png', 'S2F1Zm1hbm5TY3JpcHQub3Rm.png', 'THVjaWRhLUJvbGRJdGFsaWMub3Rm.png', 'U3RvbmVTZXJpZklUQy1TZW1pSXRhbGljLm90Zg==.png', 'Q2VyaXBoMDU2My50dGY=.png', 'V2FzaGFibGUgKHNSQikudHRm.png', 'S2VwbGVyU3RkLUJvbGRFeHREaXNwLm90Zg==.png', 'Q2hlYXAgTW90ZWwudHRm.png', 'Q2hlbHNpZXNIYW5kIFJlZ3VsYXIudHRm.png', 'RmV0dGVGcmFrdHVyLURmci5vdGY=.png', 'RG9nbWFPdXRsaW5lLnR0Zg==.png', 'RmFybmhhbURpc3BsYXktUmVn
# ...
